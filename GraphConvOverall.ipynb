# %%
import utils
utils.overall_process(mimii_dataset_SNR=6, N=16, K=3, query_size=3, train_test_ratio=0.1,
                      cnn_num_hidden_channels=32, cnn_lr=0.1, cnn_num_epochs=32,
                      gcn_embed_size=128, gcn_lr=0.005, gcn_num_epochs=300, dataset_transform=None)
# Out:
# Length of Dataset: 29
# Train Size:2  |  Test Size:27
# 波形形状: torch.Size([8, 160000])
# 波形采样率: 16000
# /home/lindenbaum/Documents/Python/DeepLearning/GCN/utils.py:319: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   plt.plot(waveform[0].T.numpy())
# Epoch:1  |  CNN_Loss :8.066
# Epoch:2  |  CNN_Loss :6.370
# Epoch:3  |  CNN_Loss :4.579
# Epoch:4  |  CNN_Loss :4.093
# Epoch:5  |  CNN_Loss :3.647
# Epoch:6  |  CNN_Loss :3.262
# Epoch:7  |  CNN_Loss :2.788
# Epoch:8  |  CNN_Loss :2.608
# Epoch:9  |  CNN_Loss :2.171
# Epoch:10  |  CNN_Loss :1.852
# Epoch:11  |  CNN_Loss :1.613
# Epoch:12  |  CNN_Loss :1.534
# Epoch:13  |  CNN_Loss :1.529
# Epoch:14  |  CNN_Loss :1.402
# ...
